# %% [markdown]
# <a href="https://colab.research.google.com/github/hrishikesh2005/iguru/blob/main/Pandas_1224iGurus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# DataFrame --> represent the data in Tabular format

emp_info = {'Id':[101,102,103] , 'Name':['John','Alex','Smith'],
            'Dept':['IT','Sales','Finance'] , 'Salary':[35000,20000,40000]}
print(emp_info)
# Out:
# {'Id': [101, 102, 103], 'Name': ['John', 'Alex', 'Smith'], 'Dept': ['IT', 'Sales', 'Finance'], 'Salary': [35000, 20000, 40000]}

# %%
data = pd.DataFrame(emp_info)
print(data)
print(type(data))
# Out:
#     Id   Name     Dept  Salary
# 0  101   John       IT   35000
# 1  102   Alex    Sales   20000
# 2  103  Smith  Finance   40000
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#     Id   Name     Dept  Salary
# 0  101   John       IT   35000
# 1  102   Alex    Sales   20000
# 2  103  Smith  Finance   40000

# %%
emp_info = {'Name':['John','Alex','Smith'],
            'Dept':['IT','Sales','Finance'] , 'Salary':[35000,20000,40000]}
data = pd.DataFrame(emp_info,index=['Emp1','Emp2','Emp3'])
data
# Out:
#        Name     Dept  Salary
# Emp1   John       IT   35000
# Emp2   Alex    Sales   20000
# Emp3  Smith  Finance   40000

# %%
print(data.shape)
# Out:
# (3, 3)

# %%
print(data['Dept'].values)
# Out:
# ['IT' 'Sales' 'Finance']

# %%
data.columns
# Out:
# Index(['Name', 'Dept', 'Salary'], dtype='object')

# %%
data[['Name','Dept']]
# Out:
#        Name     Dept
# Emp1   John       IT
# Emp2   Alex    Sales
# Emp3  Smith  Finance

# %%
# Locate Row
data.loc['Emp2']
# Out:
# Name       Alex
# Dept      Sales
# Salary    20000
# Name: Emp2, dtype: object

# %%
data.loc[['Emp1','Emp3']]
# Out:
#        Name     Dept  Salary
# Emp1   John       IT   35000
# Emp3  Smith  Finance   40000

# %%
# date_range()
# yyyymmdd
dates = pd.date_range('20250101',periods=10)
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(10,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2025-01-01  0.118032  0.190850  0.244115  0.101994
# 2025-01-02  0.410948  0.932501  0.014117  0.099217
# 2025-01-03  0.038887  0.751106  0.748449  0.992490
# 2025-01-04  0.943796  0.689568  0.229693  0.148733
# 2025-01-05  0.668682  0.407306  0.641972  0.888272
# 2025-01-06  0.683219  0.464775  0.269357  0.911681
# 2025-01-07  0.201596  0.761554  0.053225  0.466934
# 2025-01-08  0.633414  0.701598  0.848221  0.435954
# 2025-01-09  0.578265  0.540031  0.097628  0.947117
# 2025-01-10  0.427912  0.312285  0.640243  0.770370

# %%
emp_info = {'Id':[101,102,103,104,105,106] , 'Name':['John','Smith','Nurul','Tom','Harry','Smith']
            , 'Salary':[1000,2000,3000,1200,2800,3200]
            ,'Dept':['Finance','Sales','HR','IT','Marketing','Sales']}
data = pd.DataFrame(emp_info)
data
# Out:
#     Id   Name  Salary       Dept
# 0  101   John    1000    Finance
# 1  102  Smith    2000      Sales
# 2  103  Nurul    3000         HR
# 3  104    Tom    1200         IT
# 4  105  Harry    2800  Marketing
# 5  106  Smith    3200      Sales

# %%
data[data['Salary'] > 1500]
# Out:
#     Id   Name  Salary       Dept
# 1  102  Smith    2000      Sales
# 2  103  Nurul    3000         HR
# 4  105  Harry    2800  Marketing
# 5  106  Smith    3200      Sales

# %%
data[(data['Salary'] > 1500) & (data['Dept']=='Sales')]
# Out:
#     Id   Name  Salary   Dept
# 1  102  Smith    2000  Sales
# 5  106  Smith    3200  Sales

# %%
# Pandas
# Pandas is a powerful and flexible Python package that allows you to work with labeled and
# time series data. It also provides statistics methods, enables plotting, and more.
# One crucial feature of pandas is its ability to write and read Excel, CSV, and many other types of files.

# Reading An Excel File
# Reading A CSV File
# Reading tab-delimited file
# Reading A JSON File
# Uploading Local Files In Google Colab

# %%
# Reading An Excel File
# read_excel()

data = pd.read_excel('https://raw.githubusercontent.com/yash240990/Python/master/sampleExcelData.xlsx')
data
# Out:
#        id first_name   last_name                      email    gender  \
# 0       1      Merle     Draisey  mdraisey0@squarespace.com  Bigender
# 1       2      Casey      Sheach    csheach1@deviantart.com      Male
# 2       3      Darya     Leivers        dleivers2@imgur.com    Female
# 3       4     Fancie  Casebourne          fcasebourne3@g.co    Female
# 4       5    Jenilee    Vsanelli         jvsanelli4@fc2.com    Female
# ..    ...        ...         ...                        ...       ...
# 995   996     Lutero       Yurov            lyurovrn@un.org      Male
# 996   997      Verla       Peery           vpeeryro@com.com    Female
# 997   998       Fran     Langran          flangranrp@ft.com      Male
# 998   999      Gabbi     Cummins        gcumminsrq@jugem.jp    Female
# 999  1000   Gloriane        Marc   gmarcrr@businessweek.com    Female
#
#           ip_address
# 0       20.70.199.51
# 1    226.126.229.167
# 2     247.209.88.235
# 3     172.34.162.239
# ...

# %%
excelFile = pd.ExcelFile('https://raw.githubusercontent.com/yash240990/Python/master/sampleExcelData.xlsx')
excelFile.sheet_names
# Out:
# ['data', 'Sheet2']

# %%
data = pd.read_excel(excelFile,'Sheet2')
data
# Out:
#    first_name    last_name                                 email
# 0       Merle      Draisey             mdraisey0@squarespace.com
# 1       Casey       Sheach               csheach1@deviantart.com
# 2       Darya      Leivers                   dleivers2@imgur.com
# 3      Fancie   Casebourne                     fcasebourne3@g.co
# 4     Jenilee     Vsanelli                    jvsanelli4@fc2.com
# 5    Charmian    Drinkhall       cdrinkhall5@theglobeandmail.com
# 6     Janessa       Kivell                 jkivell6@linkedin.com
# 7       Mirna       Heinsh                  mheinsh7@spotify.com
# 8       Darby          Lax                   dlax8@people.com.cn
# 9       Meryl        Riehm                 mriehm9@princeton.edu
# 10       Anne        Brody                    abrodya@sphinn.com
# 11       Puff    Langsbury             plangsburyb@canalblog.com
# 12       Tina      Gregoli                  tgregolic@sfgate.com
# ...

# %%
# CSV file format
data = pd.read_csv('https://raw.githubusercontent.com/yash240990/Python/master/Position_Salaries.csv')
data
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
# tab delimited format [txt]
data = pd.read_csv('https://www.inf.ed.ac.uk/teaching/courses/inf2b/labs/iris.txt',sep='\t')
data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
# JSON Format
data = pd.read_json('https://raw.githubusercontent.com/yash240990/Python/master/simple.json')
data
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
# upload local files
from google.colab import files
upload = files.upload()               # file selection wizard
# Out:
#      <input type="file" id="files-89c008da-f37e-4847-990e-ac527884a867" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89c008da-f37e-4847-990e-ac527884a867">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls   # List The Files
# Out:
# Grade_Set_1.csv  sample_data

# %%
data = pd.read_csv('Grade_Set_1.csv')
data
# Out:
#    Hours_Studied  Test_Grade Status Result
# 0              2          57   fail      D
# 1              3          66   fail      D
# 2              4          73   pass      C
# 3              5          76   pass      C
# 4              6          79   pass      C
# 5              7          81   pass      B
# 6              8          90   pass      B
# 7              9          96   pass      A
# 8             10         100   pass      A
